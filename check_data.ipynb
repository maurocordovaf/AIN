# %%
import pandas as pd

# %%
FoodData = pd.read_csv('dataset/original/Food/FoodData.csv')
FoodData.head()
# Out:
#   AnswerID-MenuID-situation.key  AnswerID  MenuID  VirtualFlag situation  \
# 0                    2-2-normal         2       2            1    normal
# 1                    2-2-hungry         2       2            1    hungry
# 2                      2-2-full         2       2            0      full
# 3                    2-8-normal         2       8            1    normal
# 4                    2-8-hungry         2       8            1    hungry
#
#   menu_calorie menu_salt menu_genre menu_foodstuff menu_foodstyle  ...  \
# 0        large     large   Japanese           beef            SET  ...
# 1        large     large   Japanese           beef            SET  ...
# 2        large     large   Japanese           beef            SET  ...
# 3        small     large    Chinese           none            MEN  ...
# 4        small     large    Chinese           none            MEN  ...
#
#    like_bowl  like_set_menu  concious_foodstuff  like_fish  like_beaf  \
# ...
